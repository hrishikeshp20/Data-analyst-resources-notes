# %%
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')
# seaborn has its own dataset

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
Displot -- univariable(one variable)
#additional arguements
# kde =True/False
#bins = 12 Number of bars
sns.displot(tips['total_bill'], bins = 20)

# %%
#JOINT PLOT -- Combination of 2 displot
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')
#https://seaborn.pydata.org/generated/seaborn.jointplot.html

# %%
sns.pairplot(tips, hue='sex')
#creates jointplot for each and every column
#In hue pass categorical value column
#https://seaborn.pydata.org/generated/seaborn.pairplot.html

# %%
sns.rugplot(tips['total_bill'])
#same as displot but instead of bars it plots lines
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.kdeplot(tips['total_bill'])
#plots kde
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
CATEGORICAL PLOTS

# %%
sns.barplot(x='sex', y='total_bill', data=tips, estimator=np.sum)
#basically visualisation of groupby
#groupby on x so pass category column in x
#can pass any function in estimator, default is average
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.countplot(x='sex', data=tips)
#sane as barplot but just shows count
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.boxplot(x='day',y='total_bill',data=tips,hue='smoker')
#x = categorical column
#y = numeric
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day',y='total_bill',data=tips,hue='smoker')
#x = categorical column
#y = numeric
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day',y='total_bill',data=tips, jitter=True, hue ='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day',y='total_bill',data=tips)
#combination of stripplot and violin plot
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
#can stack plots on each other
sns.violinplot(x='day',y='total_bill',data=tips)
sns.swarmplot(x='day',y='total_bill',data=tips,color='black')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(x='day',y='total_bill',data=tips, kind='bar')
#General plot
#Use kind to get desired graph

# %%
GRID PLOTS

# %%
flights = sns.load_dataset('flights')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
tc = tips.corr()
tc
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tc, annot = True,cmap = 'coolwarm')
#heatmap is used for correlational data
#annot displays annotation
#cmap for color of heatmap
# Out:
# <AxesSubplot:>

# %%
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
fp = flights.pivot_table(index='month',columns='year',values='passengers')
fp
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(fp, cmap='magma')
#more arguements
#linewidth, linecolor
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.clustermap(fp, cmap='magma', standard_scale=1)
#makes hierarchy and shows similar data together
#standard_scale will change scale to 0-1

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.PairGrid(iris)
#same as pairplot but we get to chose what type of plots to plot

# %%
g = sns.PairGrid(iris)
g.map_diag(sns.histplot) #fills diagonal plots
g.map_upper(sns.scatterplot) #  fills upper diagonal plots
g.map_lower(sns.kdeplot) #fills lower diagonal plots

# %%
h = sns.FacetGrid(data=tips,col='time',row='smoker')
h.map(plt.scatter,'totalbill','tip')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [75], in <cell line: 2>()
#       1 h = sns.FacetGrid(data=tips,col='time',row='smoker')
# ----> 2 h.map(plt.scatter,'totalbill','tip')
#
# NameError: name 'plt' is not defined

# %%
data = pd.read_csv("C:\\Users\\Hrishikesh Pawar\\Downloads\\Copy of MPC001 Questions - MPC001.csv")

# %%
data
# Out:
#      Year Month  Block  Unit Section  Marks  \
# 0    2022  June      4     2       A     10
# 1    2022  June      2     2       A     10
# 2    2022  June      2     1       A     10
# 3    2022  June      4     4       A     10
# 4    2022  June      1     1       B      6
# ..    ...   ...    ...   ...     ...    ...
# 273  2011  June      1     3       B      5
# 274  2011  June      4     4       B      5
# 275  2011  June      1     2       B      5
# 276  2011  June      3     4       B      5
# 277  2011  June      2     3       B      5
#
#                                               Question
# 0    Describe the stages of problem solving and dis...
# 1    Explain J.P. Guilford’s Structure-of-Intellect...
# 2    Provide a critical evaluation of PASS theory o...
# 3    Define Problem Solving. Explain the cultural b...
# 4    Describe different research methods used in Co...
# ..                                                 ...
# ...

# %%
data.groupby('Marks').get_group(10)[data.groupby('Marks').get_group(10)['Section'] == 'D']
# Out:
# Empty DataFrame
# Columns: [Year, Month, Block, Unit, Section, Marks, Question]
# Index: []

# %%
data.groupby('Marks').get_group(10).groupby('Unit').count().sort_values('Year',ascending=False)
# Out:
#       Year  Month  Block  Section  Marks  Question
# Unit
# 2       36     36     36       36     36        36
# 4       33     33     33       33     33        33
# 1       32     32     32       32     32        32
# 3       28     28     28       28     28        28

# %%
#Total 10 mark questions = 129

#All 10 mark questions occured in Section A

#Unit 2 = 36 10 mark questions, Unit4 = 33 10 mark questions, Unit1 = 32 10 mark questions, Unit3 28 10 mark questions
